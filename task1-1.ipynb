# %%
import tushare as ts

# %%
df=ts.get_stock_basics()
df
# Out:
#         name industry area     pe  outstanding  totals  totalAssets  \
# code
# 603095   N越剑     专用机械   浙江  28.79         0.33    1.32        15.62
# 002980  N华盛昌     电器仪表   深圳  31.43         0.33    1.33         4.73
# 300325  德威新材       塑料   江苏   0.00         9.96   10.06        39.34
# 002426  胜利精密      元器件   江苏   0.00        28.26   34.42       173.31
# 000766  通化金马     化学制药   吉林  28.99         7.07    9.66        63.76
# ...      ...      ...  ...    ...          ...     ...          ...
# 688126  沪硅产业     化工原料   上海   0.00         0.00    0.00        90.40
# 603950  长源东谷     汽车配件   湖北   0.00         0.00    0.00        27.19
# 603682  锦和商业     房产服务   上海   0.00         0.00    0.00        12.83
# 603439  贵州三力     化学制药   贵州   0.00         0.00    0.00         7.31
# 603392  万泰生物     医疗保健   北京   0.00         0.00    0.00        21.65
#
#         liquidAssets  fixedAssets  reserved  ...   bvps    pb  timeToMarket  \
# code                                         ...
# ...
